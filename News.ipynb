# %%
import requests

URL="https://www.livescience.com/56048-daylight-saving-time-guide.html"

# %%
page=requests.get(URL)

# %%
print(page.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" data-locale="US" class="">\n<head>\n<meta charset="utf-8">\n<link rel="amphtml" href="https://www.livescience.com/amp/56048-daylight-saving-time-guide.html">\n<script>\nwindow.vanilla = window.vanilla || {};\nwindow.VAN = window.VAN || {};\n// For AB testing\n// We should come up with a list of feature flags\nvar defaultFlags = {"parsely":{"enabled":true},"onesignal":{"enabled":true},"gtm":{"vanilla":true,"sitespecific":true},"selligent":{"enabled":true},"sourcepoint":{"enabled":true}};\nwindow.vanilla.featureFlags = Object.assign({}, defaultFlags, window.vanilla.featureFlags || {})\nwindow.vanilla.addScript = function(src, id) {\nvar script = window.document.createElement(\'script\');\nscript.src = src;\nscript.async = true;\nscript.id = id;\nwindow.document.head.appendChild(script);\n}; </script>\n<style id="vanilla-slice-root">\n:root{ --trending-label-color: #f9ae3b;--trending-font-family: "Open Sans";--trending-background-color: #eded
# ...

# %%
from bs4 import BeautifulSoup

soup=BeautifulSoup(page.content, 'html.parser')

# %%
news_content=soup.find(id='main')

news_div=news_content.find_all('div')

# %%
news_div=news_div[2]

# %%
news_div.contents
# Out:
# [<ul class="trending__items"><span class="trending__label">Trending</span><li class="trending__item"><a class="trending__link" href="https://www.livescience.com/topics/coronavirus">Coronavirus News</a></li><li class="trending__item"><a class="trending__link" href="https://forums.livescience.com">Forum</a></li><li class="trending__item"><a class="trending__link" href="https://www.livescience.com/topics/lifes-little-mysteries">Life's Little Mysteries</a></li><li class="trending__item"><a class="trending__link" href="https://www.livescience.com/download-your-favorite-magazines.html">Magazine Deals</a></li><li class="trending__item"><a class="trending__link" href="https://teespring.com/stores/livescience-apparel">Cool Merch</a></li></ul>]
